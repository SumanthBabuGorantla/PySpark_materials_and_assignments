# %%
#/FileStore/tables/youtubedata_Assignment_7.txt
youtube=spark.read.csv("/FileStore/tables/youtubedata_Assignment_7.txt",sep="\t")
youtube.show(truncate=False)
# Out:
# +-----------+--------------------+----+----------------+---+-------+----+-----+-----+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# |_c0        |_c1                 |_c2 |_c3             |_c4|_c5    |_c6 |_c7  |_c8  |_c9        |_c10       |_c11       |_c12       |_c13       |_c14       |_c15       |_c16       |_c17       |_c18       |_c19       |_c20       |_c21       |_c22       |
# +-----------+--------------------+----+----------------+---+-------+----+-----+-----+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# ...

# %%
#1.)  what are the top five categories with maximum number of videos uploaded ?
